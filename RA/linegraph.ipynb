# %%
#%run data1_datasplit.ipynb

# %%
# pred_GBR = pred_GBR[0::40]
# GT = GT[0::40]
# ax = plt.subplot()
# ax.plot(pred_GBR, color = 'g')
# ax.plot(GT, color = 'b')
# plt.xlabel('index(every 40th value)')
# plt.ylabel('Dp')

# %%
# def visualize(df_series,anomalies):
#   ext = np.array(anomalies)
#   X_ext = ext[:,0]
#   y_ext = ext[:,1]
#   plt.plot(X_ext, y_ext, 'd', color= 'r')
#   y_value = df_series.values
#   x_axis = np.arange(len(y_value))
#   plt.plot(x_axis, y_value, '+', color= 'b')
#   plt.show()

# %%
# %run data1_no_datasplit.ipynb

# %%
# # test_data = pd.read_csv('data-2.csv')
# # test_data['index'] = test_data.index
# # temp = test_data['index'][0::40]
# # temp = temp.values
# # test_data = test_data.loc[test_data['index'].isin(temp)]
# #ax = test_data['Dp'].plot(y='Dp', style='o')
# df1 = test_data['Dp'].values
# df1 = df1[0::40]
# pred1 = pred1[0::40]
# ax = plt.subplot()
# ax.plot(df1, color = 'b')
# ax.plot(pred1, color = 'g')
# plt.xlabel('index(every 40th value)')
# plt.ylabel('Dp')

# %%
# %run adcp_no_datasplit.ipynb

# %%
# pred1 = pred1[0::3]
# test_values = test_values[0::3]
# ax = plt.subplot()
# ax.plot(pred1, color = 'g')
# ax.plot(test_values, color = 'b')
# plt.xlabel('index(every 3rd value)')
# plt.ylabel('Dp')

# %%
# %run adcp_sliding_window.ipynb

# %%
pred1 = pred1[0::3]
test_values = test_values[0::3]
ax = plt.subplot()
ax.plot(pred1, color = 'g')
ax.plot(test_values, color = 'b')
plt.xlabel('index(every 3rd value)')
plt.ylabel('Dp')
# Out:
# Text(0, 0.5, 'Dp')
